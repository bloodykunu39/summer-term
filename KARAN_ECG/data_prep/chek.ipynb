# %%
import numpy as np
np.load('disease_SB.npy')
# Out:
# array([[[-0.01 ,  0.01 ,  0.02 , ...,  0.054,  0.049,  0.   ],
#         [-0.024, -0.02 ,  0.005, ...,  0.034,  0.034, -0.015],
#         [-0.02 , -0.02 ,  0.   , ...,  0.034,  0.034, -0.01 ],
#         ...,
#         [ 0.015,  0.01 , -0.005, ..., -0.015, -0.02 ,  0.005],
#         [ 0.01 ,  0.01 ,  0.   , ..., -0.02 , -0.024,  0.   ],
#         [ 0.01 ,  0.01 ,  0.   , ..., -0.024, -0.029, -0.005]],
#
#        [[ 0.195,  0.107, -0.088, ...,  0.293,  0.273,  0.342],
#         [ 0.195,  0.107, -0.088, ...,  0.293,  0.273,  0.342],
#         [ 0.195,  0.107, -0.088, ...,  0.293,  0.273,  0.342],
#         ...,
#         [ 0.098, -0.098, -0.195, ..., -0.171,  0.01 , -0.049],
#         [ 0.088, -0.107, -0.195, ..., -0.161,  0.01 , -0.039],
#         [ 0.102, -0.098, -0.2  , ..., -0.171,  0.01 , -0.039]],
#
#        [[-0.029, -0.068, -0.039, ..., -0.049, -0.088, -0.098],
#         [-0.029, -0.068, -0.039, ..., -0.049, -0.088, -0.098],
# ...
