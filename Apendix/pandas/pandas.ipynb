# %% [markdown]
# ## pandas
# Pandas is a powerful open-source data manipulation and analysis library for Python. It provides easy-to-use data structures and data analysis tools, making it a popular choice for data scientists and analysts.
#
# With Pandas, you can easily load, manipulate, and analyze structured data. It offers a variety of data structures, such as Series (1-dimensional labeled array) and DataFrame (2-dimensional labeled data structure), which allow you to efficiently handle and analyze data.
#
# Some key features of Pandas include:
# - Data alignment and handling missing data
# - Data filtering, selection, and transformation
# - Grouping and aggregation of data
# - Merging, joining, and reshaping datasets
# - Time series analysis and handling datetime data
# - Data visualization and plotting
#
# Pandas integrates well with other libraries in the Python ecosystem, such as NumPy, Matplotlib, and scikit-learn, making it a versatile tool for data analysis and manipulation.
#
# To get started with Pandas, you can import it using the following code:
# ```python
# import pandas as pd
# ```

# %%
import pandas as pd
import numpy as np

# %%
lst=[[1,2,3],[4,5,6],[7,8,9]]
series=pd.Series(lst)
print(series)
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object

# %%
series2=pd.Series(lst,index=['a','b','c'])#index is used to give the index of the series instead of 0,1,2 we can give a,b,c
print(series2)
# Out:
# a    [1, 2, 3]
# b    [4, 5, 6]
# c    [7, 8, 9]
# dtype: object

# %%
#dictionary
cars={'BMW':100,'Audi':200,'Benz':300}
series3=pd.Series(cars)
print(series3)
df=pd.DataFrame(series3)
print(df)
# Out:
# BMW     100
# Audi    200
# Benz    300
# dtype: int64
#         0
# BMW   100
# Audi  200
# Benz  300

# %% [markdown]
# # dataframe

# %%
dict1={"name":['karan','arjun','ram'],
       'age':[20,21,22],
       'city':['delhi','mumbai','pune']}
df=pd.DataFrame(dict1)
print(dict1)
print(df)
# Out:
# {'name': ['karan', 'arjun', 'ram'], 'age': [20, 21, 22], 'city': ['delhi', 'mumbai', 'pune']}
#     name  age    city
# 0  karan   20   delhi
# 1  arjun   21  mumbai
# 2    ram   22    pune

# %%
import numpy.random as npr
my_data=npr.rand(3,4)#3 rows and 4 columns of random numbers
my_row=['A','B','C']
my_col=['W','X','Y','Z']

# %%
#create dataframe
df=pd.DataFrame(data=my_data,index=my_row,columns=my_col)
print(df)
# Out:
#           W         X         Y         Z
# A  0.848716  0.574612  0.550003  0.481592
# B  0.022889  0.494309  0.063896  0.649904
# C  0.831021  0.827232  0.994979  0.762325

# %%
#import csv File
my_df2=pd.read_csv(r'C:\Users\karan\OneDrive - Indian Institute of Science\Desktop\summer term\pandas\datacsv.csv')
print(my_df2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #import csv File
# ----> 2 my_df2=pd.read_csv(r'C:\Users\karan\OneDrive - Indian Institute of Science\Desktop\summer term\pandas\datacsv.csv')
#       3 print(my_df2)
#
# ...

# %%
#pulling out the data
print(my_df2['Temperature(K)'])
print(my_df2[['Temperature(K)','T1(s)']])
# Out:
# 0    301
# 1    303
# 2    308
# 3    313
# 4    323
# 5    333
# 6    343
# Name: Temperature(K), dtype: int64
#    Temperature(K)  T1(s)
# 0             301  0.120
# 1             303  0.136
# 2             308  0.150
# 3             313  0.160
# 4             323  0.216
# 5             333  0.235
# 6             343  0.254

# %%
#pulling rows
print(my_df2.loc[1])#loc is used to pull out the row and 1 is the index of the row
print(my_df2.loc[1:3])#pulls out the rows from 1 to 3
# Out:
# Temperature(K)    303.0000
# T1(s)               0.1360
# T2(s)               0.1480
# Tavg                0.1420
# ∆T                  0.0060
# η(mPas)             0.0031
# Name: 1, dtype: float64
#    Temperature(K)  T1(s)  T2(s)    Tavg      ∆T  η(mPas)
# 1             303  0.136  0.148  0.1420  0.0060   0.0031
# 2             308  0.150  0.152  0.1510  0.0010   0.0033
# 3             313  0.160  0.165  0.1625  0.0025   0.0035

# %%
#info
print(my_df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature(K)  7 non-null      int64
#  1   T1(s)           7 non-null      float64
#  2   T2(s)           7 non-null      float64
#  3   Tavg            7 non-null      float64
#  4   ∆T              7 non-null      float64
#  5   η(mPas)         7 non-null      float64
# dtypes: float64(5), int64(1)
# memory usage: 468.0 bytes
# None

# %%
#shape
print(my_df2.shape)#gives the shape of the dataframe
# Out:
# (7, 6)

# %%
#dimension
print(my_df2.ndim)#gives the dimension of the dataframe
# Out:
# 2

# %%
#stats
print(my_df2.describe())#gives the statistics of the dataframe
# Out:
#        Temperature(K)     T1(s)     T2(s)      Tavg        ∆T   η(mPas)
# count        7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean       317.714286  0.181571  0.186429  0.184000  0.002429  0.004000
# std         15.882005  0.052624  0.052940  0.052739  0.002130  0.001149
# min        301.000000  0.120000  0.120000  0.120000  0.000000  0.002600
# 25%        305.500000  0.143000  0.150000  0.146500  0.000750  0.003200
# 50%        313.000000  0.160000  0.165000  0.162500  0.002500  0.003500
# 75%        328.000000  0.225500  0.230000  0.227750  0.003500  0.004950
# max        343.000000  0.254000  0.260000  0.257000  0.006000  0.005600

# %%
# describe specific column
print(my_df2['Temperature(K)'].describe())
# Out:
# count      7.000000
# mean     317.714286
# std       15.882005
# min      301.000000
# 25%      305.500000
# 50%      313.000000
# 75%      328.000000
# max      343.000000
# Name: Temperature(K), dtype: float64

# %%
# describe specific column
dict1={"name":['karan','arjun','arjun','ram'],
       'age':[20,21,19,22],
       'city':['delhi','kolkata','mumbai','pune']}
df=pd.DataFrame(dict1)
print(df)
print(df['name'].describe())
# Out:
#     name  age     city
# 0  karan   20    delhi
# 1  arjun   21  kolkata
# 2  arjun   19   mumbai
# 3    ram   22     pune
# count         4
# unique        3
# top       arjun
# freq          2
# Name: name, dtype: object

# %%
#selecting rows
print(df[df['age']>20])
# Out:
#     name  age     city
# 1  arjun   21  kolkata
# 3    ram   22     pune

# %%
#selecting specific columns
print(df[['name','city']])
# Out:
#     name     city
# 0  karan    delhi
# 1  arjun  kolkata
# 2  arjun   mumbai
# 3    ram     pune

# %%
print(df.iloc[0,1])#iloc is used to pull out the data from the dataframe using the index of the row and column
# Out:
# 20

# %%
print(df.iloc[0:2,0:2])#pulls out the data from 0 to 2 rows and 0 to 2 columns
# Out:
#     name  age
# 0  karan   20
# 1  arjun   21

# %%
#by dot notation
print(df.age)
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# Name: age, dtype: int64

# %% [markdown]
# # count

# %%
dog_df=pd.read_csv('dog_data.csv')
print(dog_df)
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE            NaN     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
#count breed decending order
print(dog_df['Breed'].value_counts())
# Out:
# Breed
# MIXED                 235
# LAB MIX               185
# LABRADOR RETRIEVER    178
# GOLDEN RETRIEVER       99
# BEAGLE                 77
#                      ...
# AKITA MIX               1
# REDBONE COONHOUND       1
# MOUNTAIN CUR            1
# LOWCHEN                 1
# BRIARD SHEEPDOG         1
# Name: count, Length: 185, dtype: int64

# %%
#ascending order
print(dog_df['Breed'].value_counts(ascending=True))
# Out:
# Breed
# CATAHOULA LEOPARD D      1
# BOYKIN SPANIEL           1
# DALMATION MIX            1
# FOX TERRIER SMOOTH       1
# ENG SHEPHERD             1
#                       ...
# BEAGLE                  77
# GOLDEN RETRIEVER        99
# LABRADOR RETRIEVER     178
# LAB MIX                185
# MIXED                  235
# Name: count, Length: 185, dtype: int64

# %%
#dealing with null values
dog_df['DogName'].value_counts(dropna=False)#dropna=False will not drop the null values
# Out:
# DogName
# LUCY       35
# BELLA      30
# BAILEY     29
# BUDDY      29
# DAISY      26
#            ..
# CHOOKIE     1
# AMY         1
# DEE DEE     1
# KAYLIE      1
# GRIFFIN     1
# Name: count, Length: 1428, dtype: int64

# %%
#percentage of breed
dog_df['Breed'].value_counts(normalize=True)#normalize=True will give the percentage of the Breed and normalize=False will give the count of the Breed
# Out:
# Breed
# MIXED                 0.088015
# LAB MIX               0.069288
# LABRADOR RETRIEVER    0.066667
# GOLDEN RETRIEVER      0.037079
# BEAGLE                0.028839
#                         ...
# AKITA MIX             0.000375
# REDBONE COONHOUND     0.000375
# MOUNTAIN CUR          0.000375
# LOWCHEN               0.000375
# BRIARD SHEEPDOG       0.000375
# Name: proportion, Length: 185, dtype: float64

# %%
#count unique
print(dog_df['Color'].value_counts()['WHITE'])#gives the count of the color white
# Out:
# 226

# %%
#groupby
print(dog_df.groupby('Breed').size())#gives the count of the Breed
# Out:
# Breed
# AFFENPINSCHER           4
# AIREDALE TERRIER        5
# AKITA                   4
# AKITA MIX               1
# ALAS MALAMUTE           5
#                        ..
# WELSH SPRINGER SPAN     1
# WELSH TERRIER           1
# WIREHAIR PT GRIFFON     2
# YORKSHIRE TERR MIX     31
# YORKSHIRE TERRIER      62
# Length: 185, dtype: int64

# %%
print(dog_df.groupby('Breed').count())#gives the count of the Breed
#diff btw count and size is that count will give the count of the non null values and size will give the count of the null values also
# Out:
#                      Color  DogName  OwnerZip
# Breed
# AFFENPINSCHER            4        4         4
# AIREDALE TERRIER         5        5         5
# AKITA                    4        4         4
# AKITA MIX                1        1         1
# ALAS MALAMUTE            5        5         5
# ...                    ...      ...       ...
# WELSH SPRINGER SPAN      1        1         1
# WELSH TERRIER            1        1         1
# WIREHAIR PT GRIFFON      2        2         2
# YORKSHIRE TERR MIX      31       31        31
# YORKSHIRE TERRIER       62       62        62
#
# [185 rows x 3 columns]

# %%
dog_df.apply(lambda x: x.astype(str).value_counts())
# Out:
#         Breed  Color  DogName  OwnerZip
# 15003     NaN    NaN      NaN       4.0
# 15005     NaN    NaN      NaN       5.0
# 15006     NaN    NaN      NaN       1.0
# 15007     NaN    NaN      NaN       2.0
# 15014     NaN    NaN      NaN       2.0
# ...       ...    ...      ...       ...
# ZURI      NaN    NaN      1.0       NaN
# ZUZU      NaN    NaN      2.0       NaN
# nan       NaN    5.0      2.0       NaN
# stella    NaN    NaN      1.0       NaN
# suzie     NaN    NaN      1.0       NaN
#
# [1783 rows x 4 columns]

# %% [markdown]
# # add column

# %%
short_dog = pd.read_csv('dog_data_short.csv')
short_dog
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#by list
gender=["Male", "Female", "Male", "Male", "Female"]
short_dog['Gender']=gender
short_dog
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
# Add Default Values
short_dog["Alive/Dead"] = ["yes"]*len(short_dog)
short_dog
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        yes

# %%
# add nan values
short_dog["rank"] = np.nan
short_dog
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        yes
#
#    rank
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
# add using .insert
short_dog.insert(2, "sr.no", [1, 2, 3, 4, 5])#2 is the index of the column and Rank is the name of the column
short_dog
# Out:
#                  Breed        Color  sr.no  DogName  OwnerZip  Gender  \
# 0             COCKAPOO        BROWN      1  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN      2   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE      3     EICH     15238    Male
# 3                MIXED  BLACK/BROWN      4    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN      5   OAKLEY     15139  Female
#
#   Alive/Dead  rank
# 0        yes   NaN
# 1        yes   NaN
# 2        yes   NaN
# 3        yes   NaN
# 4        yes   NaN

# %%
# using .assign() it will create a new dataframe a copy of the original dataframe and add the new column
short_dog2=short_dog.assign(Height=[10, 20, 30, 40, 50])#Height is the name of the column and [10, 20, 30, 40, 50] is the values of the column

# %% [markdown]
# # deleting

# %%
print(short_dog2)
# Out:
#                  Breed        Color  sr.no  DogName  OwnerZip  Gender  \
# 0             COCKAPOO        BROWN      1  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN      2   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE      3     EICH     15238    Male
# 3                MIXED  BLACK/BROWN      4    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN      5   OAKLEY     15139  Female
#
#   Alive/Dead  rank  Height
# 0        yes   NaN      10
# 1        yes   NaN      20
# 2        yes   NaN      30
# 3        yes   NaN      40
# 4        yes   NaN      50

# %% [markdown]
# we have to remove let remove rank\n
# **axis 0 is rows and 1 is coloumn**

# %%
# remove coloumn rank
print(short_dog2.drop('rank', axis=1,))#it give copy of the dataframe without the rank column
short_dog2
# Out:
#                  Breed        Color  sr.no  DogName  OwnerZip  Gender  \
# 0             COCKAPOO        BROWN      1  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN      2   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE      3     EICH     15238    Male
# 3                MIXED  BLACK/BROWN      4    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN      5   OAKLEY     15139  Female
#
#   Alive/Dead  Height
# 0        yes      10
# 1        yes      20
# 2        yes      30
# 3        yes      40
# 4        yes      50
#                  Breed        Color  sr.no  DogName  OwnerZip  Gender  \
# 0             COCKAPOO        BROWN      1  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN      2   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE      3     EICH     15238    Male
# 3                MIXED  BLACK/BROWN      4    ARROW     15104    Male
# ...

# %%
# remove rank and sr.no from orignel df
print(short_dog2.drop(['rank','sr.no'], axis=1,inplace=True))#it give copy of the dataframe without the rank and sr.no column
# Out:
# None

# %%
short_dog2
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        yes
#
#    Height
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
# remove row 2
print(short_dog2.drop(2, axis=0))#it give copy of the dataframe without the row 2
print(short_dog2)#it will not remove the row 2 from the original dataframe
short_dog2.drop(2, axis=0,inplace=True)#it will remove the row 2 from the original dataframe
short_dog2
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        yes
#
#    Height
# 0      10
# 1      20
# 3      40
# 4      50
#                  Breed        Color  DogName  OwnerZip  Gender Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        yes
#
#    Height
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# ...

# %% [markdown]
# # grab row mwthod

# %%
#grab the first row
print(short_dog2.iloc[0])#it will give the 0 index row
# Out:
# Breed         COCKAPOO
# Color            BROWN
# DogName        CHARLEY
# OwnerZip         15236
# Gender            Male
# Alive/Dead         yes
# Height              10
# Name: 0, dtype: object

# %%
# 1 row dogname
print(short_dog2.loc[1]['DogName'])#it will give the dogname of the 1 index row
# Out:
# TACODA

# %%
#specific location by index
print(short_dog2.iloc[0,0])#it will give the 0 index row and 0 index column
# Out:
# COCKAPOO

# %%
#subset of the dataframe
print(short_dog2.iloc[0:2,0:2])#it will give the 0 to 2 rows and 0 to 2 columns
# Out:
#           Breed        Color
# 0      COCKAPOO        BROWN
# 1  GER SHEPHERD  BLACK/BROWN

# %%
#subset by coloumn name
#my_df.loc[['row', 'row'], ['column','column']]
print(short_dog2.loc[0:2,['DogName',"Color"]])#it will give the DogName column
# Out:
#    DogName        Color
# 0  CHARLEY        BROWN
# 1   TACODA  BLACK/BROWN

# %% [markdown]
# # conditional selection

# %%
# Conditional Selection
# > < = >= <= etc
# Return Booleans
print(dog_df=="BROWN")#it will give the boolean values of the Height column
#count Colour=BROWN
print(dog_df['Color'].value_counts()['BROWN'])#gives the count of the color BROWN
# Out:
#       Breed  Color  DogName  OwnerZip
# 0     False   True    False     False
# 1     False  False    False     False
# 2     False  False    False     False
# 3     False  False    False     False
# 4     False  False    False     False
# ...     ...    ...      ...       ...
# 2665  False   True    False     False
# 2666  False  False    False     False
# 2667  False  False    False     False
# 2668  False  False    False     False
# 2669  False  False    False     False
#
# [2670 rows x 4 columns]
# 309

# %%
#return data frame where colour is BROWN
dog_df[dog_df == "BROWN"]
# Out:
#      Breed  Color DogName  OwnerZip
# 0      NaN  BROWN     NaN       NaN
# 1      NaN    NaN     NaN       NaN
# 2      NaN    NaN     NaN       NaN
# 3      NaN    NaN     NaN       NaN
# 4      NaN    NaN     NaN       NaN
# ...    ...    ...     ...       ...
# 2665   NaN  BROWN     NaN       NaN
# 2666   NaN    NaN     NaN       NaN
# 2667   NaN    NaN     NaN       NaN
# 2668   NaN    NaN     NaN       NaN
# 2669   NaN    NaN     NaN       NaN
#
# [2670 rows x 4 columns]

# %%
#return other values as it is show only brown colour
dog_df[(dog_df["Color"] == "BROWN")]
# Out:
#                    Breed  Color           DogName  OwnerZip
# 0               COCKAPOO  BROWN           CHARLEY     15236
# 12      AM PITT BULL MIX  BROWN              KING     15235
# 25            BEAGLE MIX  BROWN  CHRISTINA "TINA"     15025
# 38            BEAGLE MIX  BROWN        HONEY PUCK     15241
# 39             CHIHUAHUA  BROWN              ROXY     15147
# ...                  ...    ...               ...       ...
# 2652  LABRADOR RETRIEVER  BROWN            WESTIN     15237
# 2657        GER SHEPHERD  BROWN             SARAH     15239
# 2660              PUGGLE  BROWN              MACY     15044
# 2663  LABRADOR RETRIEVER  BROWN              NINO     15102
# 2665        GOLDENDOODLE  BROWN           WINSLOW     15044
#
# [309 rows x 4 columns]

# %%
#return data frame where colour is BROWN and breed is brown
dog_df[dog_df == "BROWN"][["Color", "Breed"]]
# Out:
#       Color Breed
# 0     BROWN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ...     ...   ...
# 2665  BROWN   NaN
# 2666    NaN   NaN
# 2667    NaN   NaN
# 2668    NaN   NaN
# 2669    NaN   NaN
#
# [2670 rows x 2 columns]

# %% [markdown]
# # multiple selection

# %%
#multiple conditions
print(dog_df[(dog_df["Color"] == "BROWN") & (dog_df["Breed"] == "MIXED")].head())#head() will give the top 5 rows
#length
print("\n",len(dog_df[(dog_df["Color"] == "BROWN") & (dog_df["Breed"] == "MIXED")]))
# Out:
#      Breed  Color    DogName  OwnerZip
# 42   MIXED  BROWN     STELLA     15044
# 272  MIXED  BROWN       HANK     15220
# 371  MIXED  BROWN      TEDDY     15136
# 402  MIXED  BROWN  GEORGIOUS     15212
# 505  MIXED  BROWN    HERSHEY     15071
#
#  38

# %%
#using or
print(dog_df[(dog_df["Color"] == "BROWN") | (dog_df["Breed"] == "MIXED")].head())#note we use | instead of "or"
print("\n",len(dog_df[(dog_df["Color"] == "BROWN") | (dog_df["Breed"] == "MIXED")]))
# Out:
#                Breed        Color           DogName  OwnerZip
# 0           COCKAPOO        BROWN           CHARLEY     15236
# 3              MIXED  BLACK/BROWN             ARROW     15104
# 12  AM PITT BULL MIX        BROWN              KING     15235
# 15             MIXED        WHITE             RUSTY     15120
# 25        BEAGLE MIX        BROWN  CHRISTINA "TINA"     15025
#
#  506

# %%
#we wannt specefic coloumns after applying the condition
print(dog_df[(dog_df["Color"] == "BROWN") & (dog_df["Breed"] == "MIXED")][["DogName", "Color"]])
# Out:
#             DogName  Color
# 42           STELLA  BROWN
# 272            HANK  BROWN
# 371           TEDDY  BROWN
# 402       GEORGIOUS  BROWN
# 505         HERSHEY  BROWN
# 523   MINDY MAZUREK  BROWN
# 572           STEVE  BROWN
# 584            BEAR  BROWN
# 602           CHLOE  BROWN
# 818          PEANUT  BROWN
# 943         DEE DEE  BROWN
# 946            SAGE  BROWN
# 948           BELLA  BROWN
# 995          MISTER  BROWN
# 1006        VANESSA  BROWN
# 1042           JACK  BROWN
# 1123         BUDDIE  BROWN
# 1195         COOPER  BROWN
# 1204            POE  BROWN
# 1211          EPPEY  BROWN
# 1258           BLUE  BROWN
# 1322         PHOEBE  BROWN
# 1466          JAXIE  BROWN
# 1476          PIPPA  BROWN
# 1659         ISABEL  BROWN
# 1780         WILBUR  BROWN
# 1798           PINO  BROWN
# 1847         MICKEY  BROWN
# 2180           KONA  BROWN
# 2351          BELLA  BROWN
# 2393         PEANUT  BROWN
# 2403           TOBY  BROWN
# 2430           LUCY  BROWN
# ...

# %% [markdown]
# # Reset the index

# %%
short_dog = pd.read_csv('dog_data_short.csv')
print(short_dog)
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#setting column as index
short_dog.set_index("OwnerZip")#it will set the OwnerZip as the index of the dataframe but it will not change the original dataframe
# Out:
#                         Breed        Color  DogName
# OwnerZip
# 15236                COCKAPOO        BROWN  CHARLEY
# 15238            GER SHEPHERD  BLACK/BROWN   TACODA
# 15238           BELG MALINOIS      BRINDLE     EICH
# 15104                   MIXED  BLACK/BROWN    ARROW
# 15139     AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY

# %%
#change the original dataframe
short_dog.set_index("OwnerZip", inplace=True)#it will set the OwnerZip as the index of the dataframe and it will change the original dataframe

# %%
short_dog
# Out:
#                         Breed        Color  DogName
# OwnerZip
# 15236                COCKAPOO        BROWN  CHARLEY
# 15238            GER SHEPHERD  BLACK/BROWN   TACODA
# 15238           BELG MALINOIS      BRINDLE     EICH
# 15104                   MIXED  BLACK/BROWN    ARROW
# 15139     AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY

# %%
# reset
short_dog.reset_index(inplace=True)#it will reset the index of the dataframe and it will change the original dataframe

# %%
short_dog
# Out:
#    OwnerZip                Breed        Color  DogName
# 0     15236             COCKAPOO        BROWN  CHARLEY
# 1     15238         GER SHEPHERD  BLACK/BROWN   TACODA
# 2     15238        BELG MALINOIS      BRINDLE     EICH
# 3     15104                MIXED  BLACK/BROWN    ARROW
# 4     15139  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY

# %% [markdown]
# # dealing with imcomplete

# %%
# Create Dummny Data
stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,8,9], 'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
#delete the nan row
my_df.dropna()#it will delete the row which has nan values
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %%
#delete the nan column
stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,8,9], 'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df.dropna(axis=1)#it will delete the column which has nan values
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
#remove permenantly
my_df.dropna(axis=1,inplace=True)#it will delete the column which has nan values and it will change the original dataframe

# %%
#removing the row but it should cross some threshold
stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,np.nan,9], 'D':[10,11,np.nan]}
my_df = pd.DataFrame(stuff)
print(my_df)
my_df.dropna(thresh=3)#it will delete the row which has 2 or more nan values
# Out:
#    A    B    C     D
# 0  1  4.0  7.0  10.0
# 1  2  NaN  NaN  11.0
# 2  3  6.0  9.0   NaN
#    A    B    C     D
# 0  1  4.0  7.0  10.0
# 2  3  6.0  9.0   NaN

# %%
#fill null values   
stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,np.nan,9], 'D':[10,11,np.nan]}
my_df = pd.DataFrame(stuff)
my_df.fillna(value="lol")#it will fill the nan values with lol
# Out:
#    A    B    C     D
# 0  1  4.0  7.0  10.0
# 1  2  lol  lol  11.0
# 2  3  6.0  9.0   lol

# %%
#fill null values with mean
stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,np.nan,9], 'D':[10,11,np.nan]}
my_df = pd.DataFrame(stuff)
my_df.fillna(value=my_df.mean())#it will fill the nan values with the mean of the column
# Out:
#    A    B    C     D
# 0  1  4.0  7.0  10.0
# 1  2  5.0  8.0  11.0
# 2  3  6.0  9.0  10.5

# %% [markdown]
# # group by

# %%
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150]}
# Create Dataframe
grp_df = pd.DataFrame(stuff)
grp_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
#group by company
corp_df=grp_df.groupby('Corporation')#it will group the dataframe by the Corporation
corp_df

# %%
#sum of salary
corp_df.sum(numeric_only=True)#it will give the sum of the salary of the Corporation
# Out:
#              Salary
# Corporation
# Apple           330
# Google          340
# Meta            340

# %%
corp_df.mean(numeric_only=True)#it will give the mean of the salary of the Corporation
# Out:
#              Salary
# Corporation
# Apple         165.0
# Google        170.0
# Meta          170.0

# %%
#max salary
corp_df.max()#it will give the max of salry as max of string is the last alphabetically and in salary it is the max value 
#max employe and max salary are not corelated
# Out:
#             Employees  Salary
# Corporation
# Apple            John     200
# Google         Justin     220
# Meta              Wes     190

# %%
corp_df.min(numeric_only=True)#it will give the min of the salary of the Corporation
# Out:
#              Salary
# Corporation
# Apple           130
# Google          120
# Meta            150

# %%
#variance
corp_df.var(numeric_only=True)#it will give the variance of the salary of the Corporation
#we can use more statistical functions like std,median etc
# Out:
#              Salary
# Corporation
# Apple        2450.0
# Google       5000.0
# Meta          800.0

# %% [markdown]
# #we can use more statistical functions like std,median etc

# %%
corp_df.describe()#it will give the statistics of the salary of the Corporation
# Out:
#             Salary
#              count   mean        std    min    25%    50%    75%    max
# Corporation
# Apple          2.0  165.0  49.497475  130.0  147.5  165.0  182.5  200.0
# Google         2.0  170.0  70.710678  120.0  145.0  170.0  195.0  220.0
# Meta           2.0  170.0  28.284271  150.0  160.0  170.0  180.0  190.0

# %% [markdown]
# # UNIQUE

# %%
dog_df = pd.read_csv('dog_data.csv')
dog_df["DogName"].value_counts()#it will give the count of the DogName
# Out:
# DogName
# LUCY       35
# BELLA      30
# BAILEY     29
# BUDDY      29
# DAISY      26
#            ..
# CHOOKIE     1
# AMY         1
# DEE DEE     1
# KAYLIE      1
# GRIFFIN     1
# Name: count, Length: 1427, dtype: int64

# %%
#unique name
dog_df["DogName"].unique()#it will give the unique names of the DogName
# Out:
# array(['CHARLEY', 'TACODA', 'EICH', ..., 'WINSLOW', 'ROCKY KALAKOS',
#        'GRIFFIN'], dtype=object)

# %%
uniquename_Df=pd.DataFrame(dog_df["DogName"].unique())#it will give the unique names of the DogName in the dataframe
uniquename_Df
# Out:
#                   0
# 0           CHARLEY
# 1            TACODA
# 2              EICH
# 3             ARROW
# 4            OAKLEY
# ...             ...
# 1423          MARGE
# 1424           NINO
# 1425        WINSLOW
# 1426  ROCKY KALAKOS
# 1427        GRIFFIN
#
# [1428 rows x 1 columns]

# %% [markdown]
# # APPLY
# The `apply()` function in pandas is used to apply a function along an axis of a DataFrame or Series. It allows you to apply a custom function to each element or row/column of the DataFrame or Series.
#
# The basic syntax of the `apply()` function is as follows:
#
# ```python
# df.apply(func, axis=0)
# ```

# %%
grp_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
#create a new function
#we want to increase salary as x=greatest int(2x+sqroot(x) )
def increase_salary(x):
    return int(2*x+np.sqrt(x))

# %%
#apply the function
grp_df["Salary"].apply(increase_salary)#it will apply the function to the salary column of the dataframe
#gives output in the form of series
# Out:
# 0    414
# 1    454
# 2    393
# 3    271
# 4    250
# 5    312
# Name: Salary, dtype: int64

# %%
#change also in orignal
grp_df["Salary"]=grp_df["Salary"].apply(increase_salary)#it will apply the function to the salary column of the dataframe and change the original dataframe
grp_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     414
# 1      Google     April     454
# 2        Meta       Wes     393
# 3       Apple      Beth     271
# 4      Google    Justin     250
# 5        Meta     Steph     312

# %%
#using lambda
grp_df["Salary"].apply(lambda x: int(2*x+np.sqrt(x)))#it will apply the lambda function to the salary column of the dataframe and change the original dataframe
# Out:
# 0    848
# 1    929
# 2    805
# 3    558
# 4    515
# 5    641
# Name: Salary, dtype: int64

# %% [markdown]
# ## for multiple coloumn

# %%
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150],
}
# Create Dataframe
comp_df = pd.DataFrame(stuff)
comp_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
#fxn for multiple coloumn
def namer(x):
    return x+" is a good"

# %%
comp_df[["Employees","Corporation"]].apply(namer)#it will apply the function to the Employees column of the dataframe
# Out:
#           Employees       Corporation
# 0    John is a good   Apple is a good
# 1   April is a good  Google is a good
# 2     Wes is a good    Meta is a good
# 3    Beth is a good   Apple is a good
# 4  Justin is a good  Google is a good
# 5   Steph is a good    Meta is a good

# %% [markdown]
# # sorting

# %%
#sort salary in ascending order
comp_df.sort_values(by='Salary')#it will sort the dataframe by the Salary column in ascending order
# Out:
#   Corporation Employees  Salary
# 4      Google    Justin     120
# 3       Apple      Beth     130
# 5        Meta     Steph     150
# 2        Meta       Wes     190
# 0       Apple      John     200
# 1      Google     April     220

# %%
#in decending order
comp_df.sort_values(by='Salary',ascending=False)#it will sort the dataframe by the Salary column in decending order
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %% [markdown]
# #  histogram and mathplotlib

# %%
import matplotlib as plt
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])

# %%
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.120906 -2.121784 -1.217708 -1.055322
# 1  -1.330756  0.495824 -0.085738  0.103746
# 2  -0.946642  0.443385 -0.537803  0.018005
# 3   0.249366  0.216147 -1.388116 -1.034050
# 4   0.239326  1.175491  0.537608 -0.729080
# ..       ...       ...       ...       ...
# 95 -0.136090 -0.030973 -0.958406 -1.644085
# 96 -1.364136 -1.798071  0.593683 -0.135072
# 97  0.948525  1.231091  0.839412 -2.313151
# 98 -0.499045 -0.846738  0.105002  0.648885
# 99 -0.098075  0.932043  0.326240  0.241974
#
# [100 rows x 4 columns]

# %%
#histogram
my_df["Mon"].hist()#it will give the histogram of the Mon column
# Out:
# <Axes: >

# %%
my_df["Mon"].hist(bins=30)#it will give the histogram of the Mon column with 30 bins
# Out:
# <Axes: >

# %%
my_df["Tues"].hist()
# Out:
# <Axes: >

# %%
#without bar
my_df["Mon"].plot(kind='hist',bins=50)#it will give the histogram of the Mon column
# Out:
# <Axes: ylabel='Frequency'>

# %%
#legend
my_df.plot(kind='hist',bins=50,legend=True)#it will give the histogram of the dataframe
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## areal plot

# %%
#areal plot
my_df = pd.DataFrame(randn(25, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df.plot(kind='area',stacked=False)#it will give the areal plot of the dataframe
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind='area',stacked=False)#it will give the areal plot of the dataframe
# Out:
# <Axes: >

# %%
#shading
my_df.abs().plot(kind='area',stacked=False,alpha=0.5)#alpha will make graph transparent
# Out:
# <Axes: >

# %%
#title adding and removing legend
my_df.plot(kind='area',stacked=False,alpha=0.5,title="areal graph",legend=False)#alpha will make graph transparent
# Out:
# <Axes: title={'center': 'areal graph'}>

# %%
#table
my_df['Mon'].plot(kind='area',stacked=False,alpha=0.5,title="areal graph",legend=False,table=True)#alpha will make graph transparent
# Out:
# <Axes: title={'center': 'areal graph'}>

# %% [markdown]
# ## bar chart

# %%
#bar chart
my_df.abs().plot(kind='bar')#it will give the bar chart of the dataframe
# Out:
# <Axes: >

# %%
#stacked
my_df.abs().plot(kind='bar',stacked=True)#it will give the stacked bar chart of the dataframe
# Out:
# <Axes: >

# %%
# Second Way
my_df.abs().plot.bar()
# Out:
# <Axes: >

# %%
my_df.abs().plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
#adding gird line
my_df.abs().plot.bar(stacked=True,grid=True)#it will give the stacked bar chart of the dataframe with grid lines
# Out:
# <Axes: >

# %% [markdown]
# ## line chart

# %%
#line chart
my_df.plot(kind='line')#it will give the line chart of the dataframe
# Out:
# <Axes: >

# %%
#change line width
my_df.plot(kind='line',linewidth=5)#it will give the line chart of the dataframe with line width 5
# Out:
# <Axes: >

# %%
#change size
my_df[['Mon', 'Tues']].abs().plot(kind="line", figsize=(10,5))
# Out:
# <Axes: >

# %%
#second way
my_df.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# # scatter plot in pandas

# %%
#sccater plot
my_df.plot(kind='scatter',x='Mon',y='Tues')#we have to assign the axis
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='scatter',x='Mon',y='Tues',c="Wed")#we have to assign the axis
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
#change colour
my_df.plot(kind='scatter',x='Mon',y='Tues',c="Wed",cmap='coolwarm')#we have to assign the axis
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
#by size 
my_df.plot(kind='scatter',x='Mon',y='Tues',s=my_df['Wed']*100,alpha=0.3)#we have to assign the axis
# Out:
# c:\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %% [markdown]
# # box plot

# %%
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.650526  0.467568  1.345276  0.107637
# 1   -0.428450  0.145933 -0.987132 -1.371375
# 2   -1.209641 -0.717850 -1.118768  0.436522
# 3    0.345859 -0.160740  1.001965  0.113646
# 4    1.019275 -1.375806  0.948098 -0.451142
# ..        ...       ...       ...       ...
# 495  0.465282  2.252227  0.904588 -1.380503
# 496  1.153576 -0.029535  2.420193 -0.330368
# 497  0.376340 -0.479316 -0.858232  0.969405
# 498 -1.057408  0.294796 -0.810785 -0.535145
# 499 -1.026759  0.469752  0.504683  0.439816
#
# [500 rows x 4 columns]

# %%
#box plot
my_df.plot(kind='box')#it will give the box plot of the dataframe
# Out:
# <Axes: >

# %% [markdown]
# ## hex plots

# %%
my_df.plot(kind="hexbin",x="Mon",y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
#change grid size
my_df.plot(kind="hexbin",x="Mon",y="Tues",gridsize=25,cmap="magma")
#darker spot will twll more count
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %% [markdown]
# ## density plots

# %%
#density plot
# %matplotlib inline
import scipy as sp

# %%
my_df.plot(kind='kde')#it will give the density plot of the Mon column
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # liner regresion model

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...
